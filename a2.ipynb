# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
import numpy as np
import time
import copy
from sklearn.metrics import precision_score, f1_score, confusion_matrix
import seaborn as sns
import os
import sys
from datetime import datetime

# %% [markdown]
# Select device and using logger for report

# %%
# Base directory for storing all experiment results
base_output_dir = "experiment_results"
os.makedirs(base_output_dir, exist_ok=True)

def create_experiment_dir(base_dir=base_output_dir):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    exp_dir = os.path.join(base_dir, f"experiment_{timestamp}")
    os.makedirs(exp_dir, exist_ok=True)  # Ensure directory creation is safe
    return exp_dir

class Logger:
    def __init__(self, filename):
        self.terminal = sys.stdout
        self.log = open(filename, "a")  # Append mode to keep previous logs

    def write(self, message):
        self.terminal.write(message)
        self.log.write(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')} - {message}")  # Add timestamp
        self.flush()

    def flush(self):
        # Ensure both streams are flushed immediately 
        self.terminal.flush()
        self.log.flush()

    def __del__(self):
        self.log.close()  # Ensure the log file is closed when the object is deleted

# Set up device - use GPU if available, otherwise CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# data pre-processing

# %%
# Data augmentation and normalization for training
transform_train = transforms.Compose([
   transforms.RandomCrop(32, padding=4),
   transforms.RandomHorizontalFlip(),
   transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # Color jitter
   transforms.RandomRotation(15),  # Random rotation
   transforms.ToTensor(),
   transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# Only normalization for testing/validation
transform_test = transforms.Compose([
   transforms.ToTensor(),
   transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# Set data path variable
data_path = "./data"
full_trainset = datasets.CIFAR10(root=data_path, train=True, download=True, transform=transform_train)

# Dynamically calculate training and validation set sizes
total_size = len(full_trainset)
train_size = int(0.9 * total_size)
val_size = total_size - train_size
trainset, valset = random_split(full_trainset, [train_size, val_size])

# Load test set
testset = datasets.CIFAR10(root=data_path, train=False, download=True, transform=transform_test)

# Create data loaders
trainloader = DataLoader(trainset, batch_size=128, shuffle=True, num_workers=2)
valloader = DataLoader(valset, batch_size=100, shuffle=False, num_workers=2)
testloader = DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

# CIFAR10 classes
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
   """
   Train and validate the model over specified epochs
   Returns trained model and training history
   """
   since = time.time()
   best_model_wts = copy.deepcopy(model.state_dict())
   best_acc = 0.0
   
   # Initialize history lists for tracking metrics
   train_loss_history = []
   train_acc_history = []
   val_loss_history = []
   val_acc_history = [] 

   for epoch in range(num_epochs):
       print(f'Epoch {epoch}/{num_epochs - 1}')
       print('-' * 10)
       # Each epoch has a training and validation phase
       for phase in ['train', 'val']:
           if phase == 'train':
               model.train() 
               dataloader = trainloader
           else:
               model.eval()  
               dataloader = valloader

           running_loss = 0.0
           running_corrects = 0
           # Iterate over data batches
           for inputs, labels in dataloader:
               inputs = inputs.to(device)
               labels = labels.to(device)

               # Zero the parameter gradients
               optimizer.zero_grad()

               # Forward pass
               # Track history only in train phase
               with torch.set_grad_enabled(phase == 'train'):
                   outputs = model(inputs)
                   _, preds = torch.max(outputs, 1)
                   loss = criterion(outputs, labels)

                   # Backward pass + optimize only in training phase
                   if phase == 'train':
                       loss.backward()
                       optimizer.step()
               # Statistics
               running_loss += loss.item() * inputs.size(0)
               running_corrects += torch.sum(preds == labels.data)

           # Learning rate scheduling
           if phase == 'train':
               scheduler.step()

           # Calculate epoch metrics
           epoch_loss = running_loss / len(dataloader.dataset)
           epoch_acc = running_corrects.double() / len(dataloader.dataset)

           print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

           # Record history
           if phase == 'train':
               train_loss_history.append(epoch_loss)
               train_acc_history.append(epoch_acc.cpu().numpy())
           else:
               val_loss_history.append(epoch_loss)
               val_acc_history.append(epoch_acc.cpu().numpy())

           # Save best model
           if phase == 'val' and epoch_acc > best_acc:
               best_acc = epoch_acc
               best_model_wts = copy.deepcopy(model.state_dict())

   # Print training time and load best model
   time_elapsed = time.time() - since
   print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
   print(f'Best val Acc: {best_acc:4f}')
   model.load_state_dict(best_model_wts)
   
   return model, train_loss_history, train_acc_history, val_loss_history, val_acc_history

def evaluate_model(model, dataloader):
   """
   Evaluate model performance and calculate metrics
   Returns accuracy, precision, F1 score and predictions
   """
   model.eval()
   all_preds = []
   all_labels = []
   
   # Predict without gradient computation
   with torch.no_grad():
       for inputs, labels in dataloader:
           inputs = inputs.to(device)
           labels = labels.to(device)
           outputs = model(inputs)
           _, preds = torch.max(outputs, 1)
           all_preds.extend(preds.cpu().numpy())
           all_labels.extend(labels.cpu().numpy())
   
   # Calculate metrics
   all_preds = np.array(all_preds)
   all_labels = np.array(all_labels)
   accuracy = (all_preds == all_labels).mean()
   precision = precision_score(all_labels, all_preds, average='macro')
   f1 = f1_score(all_labels, all_preds, average='macro')
   
   return accuracy, precision, f1, all_preds, all_labels

# %%
def plot_training_history(train_loss, train_acc, val_loss, val_acc, save_path):
   """
   Plot training/validation loss and accuracy curves
   Save the plot to specified path
   """
   plt.figure(figsize=(12, 4))
   
   # Plot loss
   plt.subplot(1, 2, 1)
   plt.plot(train_loss, label='Train Loss')
   plt.plot(val_loss, label='Validation Loss')
   plt.xlabel('Epoch')
   plt.ylabel('Loss')
   plt.legend()
   plt.title('Training and Validation Loss')

   # Plot accuracy
   plt.subplot(1, 2, 2)
   plt.plot(train_acc, label='Train Accuracy') 
   plt.plot(val_acc, label='Validation Accuracy')
   plt.xlabel('Epoch')
   plt.ylabel('Accuracy') 
   plt.legend()
   plt.title('Training and Validation Accuracy')
   
   plt.tight_layout()
   plt.savefig(save_path)
   plt.close()

def plot_confusion_matrix(y_true, y_pred, classes, save_path):
   """
   Create and save confusion matrix heatmap
   """
   cm = confusion_matrix(y_true, y_pred)
   plt.figure(figsize=(10, 8))
   sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
               xticklabels=classes, yticklabels=classes)
   plt.title('Confusion Matrix')
   plt.xlabel('Predicted')
   plt.ylabel('True')
   plt.tight_layout()
   plt.savefig(save_path)
   plt.close()

def print_results(model_name, best_val_acc, test_acc, test_precision, test_f1, train_time):
   """
   Print evaluation metrics in a formatted way
   """
   print(f"Results for {model_name}:")
   print(f"Best Validation Accuracy: {best_val_acc:.4f}")
   print(f"Test Accuracy: {test_acc:.4f}")
   print(f"Test Precision: {test_precision:.4f}")
   print(f"Test F1 Score: {test_f1:.4f}")
   print(f"Training Time: {train_time:.2f} seconds")
   print("-" * 40)

# %%
from torchvision.models import resnet18, ResNet18_Weights
def train_resnet18(lr=0.01, momentum=0.9, weight_decay=5e-4, exp_dir=None):
    
   model = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
   num_ftrs = model.fc.in_features
   model.fc = nn.Linear(num_ftrs, 10) 
   model = model.to(device)

   # Define loss function and optimizer
   criterion = nn.CrossEntropyLoss()
   optimizer = optim.SGD(model.parameters(), 
                        lr=lr, 
                        momentum=momentum, 
                        weight_decay=weight_decay)
   
   # Learning rate scheduler: reduce the learning rate by a factor of 0.1 every 7 epochs
   scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

   # Train the model and record the time taken
   start_time = time.time()
   model, train_loss, train_acc, val_loss, val_acc = train_model(
       model, criterion, optimizer, scheduler, num_epochs=25)
   end_time = time.time()

   # Plot training curves
   plot_training_history(train_loss, train_acc, val_loss, val_acc, 
                        os.path.join(exp_dir, 'resnet18_training_history.png'))
   
   # Evaluate the model on the test set and print evaluation metrics
   test_acc, test_precision, test_f1, y_pred, y_true = evaluate_model(model, testloader)
   print_results("ResNet18", max(val_acc), test_acc, test_precision, test_f1, 
                end_time - start_time)
   
   # Plot confusion matrix
   plot_confusion_matrix(y_true, y_pred, classes, 
                        os.path.join(exp_dir, 'resnet18_confusion_matrix.png'))

# %%
from torchvision.models import vgg16, VGG16_Weights
def train_vgg16(lr=0.01, momentum=0.9, weight_decay=5e-4, exp_dir=None):

   model = vgg16(weights=VGG16_Weights.IMAGENET1K_V1)
   num_ftrs = model.classifier[6].in_features 
   model.classifier[6] = nn.Linear(num_ftrs, 10) 
   model = model.to(device)

   # Define loss function and optimizer, using the same hyperparameters as ResNet18
   criterion = nn.CrossEntropyLoss()
   optimizer = optim.SGD(model.parameters(), 
                        lr=lr,
                        momentum=momentum, 
                        weight_decay=weight_decay)
   
   # Learning rate scheduler: reduces the learning rate by a factor of 0.1 every 7 epochs
   scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

   # Train the model and record the time taken
   start_time = time.time()
   model, train_loss, train_acc, val_loss, val_acc = train_model(
       model, criterion, optimizer, scheduler, num_epochs=25)
   end_time = time.time()

   # Plot training curves
   plot_training_history(train_loss, train_acc, val_loss, val_acc,
                        os.path.join(exp_dir, 'vgg16_training_history.png'))
   
   # Evaluate the model on the test set and print evaluation metrics
   test_acc, test_precision, test_f1, y_pred, y_true = evaluate_model(model, testloader)
   print_results("VGG16", max(val_acc), test_acc, test_precision, test_f1,
                end_time - start_time)
   
   # Plot confusion matrix
   plot_confusion_matrix(y_true, y_pred, classes,
                        os.path.join(exp_dir, 'vgg16_confusion_matrix.png'))

# %%
from torchvision.models import mobilenet_v2, MobileNet_V2_Weights
def train_mobilenetv2(lr=0.01, momentum=0.9, weight_decay=5e-4, exp_dir=None):
   
   # Use 'weights' instead of 'pretrained'
   model = models.mobilenet_v2(weights=MobileNet_V2_Weights.IMAGENET1K_V1)
   num_ftrs = model.classifier[1].in_features 
   model.classifier[1] = nn.Linear(num_ftrs, 10) 
   model = model.to(device)

   # Define loss function and optimizer
   criterion = nn.CrossEntropyLoss()
   optimizer = optim.SGD(model.parameters(), 
                         lr=lr, 
                         momentum=momentum, 
                         weight_decay=weight_decay)
   
   # Learning rate scheduler: reduce LR by 0.1 every 7 epochs
   scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

   # Train the model and record time
   start_time = time.time()
   model, train_loss, train_acc, val_loss, val_acc = train_model(
       model, criterion, optimizer, scheduler, num_epochs=25)
   end_time = time.time()

   # Plot training history
   plot_training_history(train_loss, train_acc, val_loss, val_acc,
                         os.path.join(exp_dir, 'mobilenetv2_training_history.png'))
   
   # Evaluate on test set and print metrics
   test_acc, test_precision, test_f1, y_pred, y_true = evaluate_model(model, testloader)
   print_results("MobileNetV2", max(val_acc), test_acc, test_precision, test_f1,
                 end_time - start_time)
   
   # Plot confusion matrix
   plot_confusion_matrix(y_true, y_pred, classes,
                         os.path.join(exp_dir, 'mobilenetv2_confusion_matrix.png'))

# %%
def run_experiments():

   # Create a new experiment directory with a timestamp
   exp_dir = create_experiment_dir()
   
   # Set up logging, saving console output to a file
   sys.stdout = Logger(os.path.join(exp_dir, 'experiment_log.txt'))

   # MobileNetV2 experiments with two sets of hyperparameters
   print("\nStarting MobileNetV2 experiments...")
   # Default settings
   train_mobilenetv2(lr=0.01, momentum=0.9, weight_decay=5e-4, exp_dir=exp_dir)
   # Modified settings with a lower learning rate and higher momentum
   train_mobilenetv2(lr=0.001, momentum=0.95, weight_decay=1e-4, exp_dir=exp_dir)

   # ResNet18 experiments using the same hyperparameter variations
   print("Starting ResNet18 experiments...")
   train_resnet18(lr=0.01, momentum=0.9, weight_decay=5e-4, exp_dir=exp_dir)
   train_resnet18(lr=0.001, momentum=0.95, weight_decay=1e-4, exp_dir=exp_dir)

   # VGG16 experiments using the same hyperparameter variations
   print("\nStarting VGG16 experiments...")
   train_vgg16(lr=0.01, momentum=0.9, weight_decay=5e-4, exp_dir=exp_dir)
   train_vgg16(lr=0.001, momentum=0.95, weight_decay=1e-4, exp_dir=exp_dir)

   # Restore standard output
   sys.stdout = sys.__stdout__

# %%
if __name__ == "__main__":
    run_experiments()
# Out:
# Starting MobileNetV2 experiments...
# Epoch 0/24
# ----------
# train Loss: 1.4095 Acc: 0.5074
# val Loss: 1.1233 Acc: 0.5976
# Epoch 1/24
# ----------
# train Loss: 1.0203 Acc: 0.6436
# val Loss: 0.9346 Acc: 0.6714
# Epoch 2/24
# ----------
# train Loss: 0.8939 Acc: 0.6913
# val Loss: 0.9088 Acc: 0.6820
# Epoch 3/24
# ----------
# train Loss: 0.8533 Acc: 0.7030
# val Loss: 0.8376 Acc: 0.7076
# Epoch 4/24
# ----------
# train Loss: 0.8177 Acc: 0.7148
# val Loss: 0.7887 Acc: 0.7262
# Epoch 5/24
# ----------
# train Loss: 0.8331 Acc: 0.7106
# val Loss: 0.8911 Acc: 0.6916
# Epoch 6/24
# ----------
# train Loss: 0.7927 Acc: 0.7246
# val Loss: 0.8045 Acc: 0.7152
# Epoch 7/24
# ----------
# train Loss: 0.6818 Acc: 0.7604
# val Loss: 0.6801 Acc: 0.7658
# Epoch 8/24
# ----------
# train Loss: 0.6394 Acc: 0.7741
# val Loss: 0.6635 Acc: 0.7740
# Epoch 9/24
# ----------
# train Loss: 0.6266 Acc: 0.7792
# val Loss: 0.6553 Acc: 0.7742
# Epoch 10/24
# ----------
# train Loss: 0.6159 Acc: 0.7824
# val Loss: 0.6501 Acc: 0.7744
# Epoch 11/24
# ----------
# train Loss: 0.6041 Acc: 0.7865
# val Loss: 0.6512 Acc: 0.7734
# Epoch 12/24
# ----------
# train Loss: 0.5955 Acc: 0.7897
# val Loss: 0.6378 Acc: 0.7812
# Epoch 13/24
# ----------
# train Loss: 0.5917 Acc: 0.7920
# val Loss: 0.6247 Acc: 0.7834
# Epoch 14/24
# ----------
# train Loss: 0.5837 Acc: 0.7959
# val Loss: 0.6234 Acc: 0.7890
# Epoch 15/24
# ----------
# train Loss: 0.5797 Acc: 0.7945
# val Loss: 0.6200 Acc: 0.7852
# Epoch 16/24
# ----------
# train Loss: 0.5775 Acc: 0.7953
# val Loss: 0.6157 Acc: 0.7880
# Epoch 17/24
# ----------
# train Loss: 0.5694 Acc: 0.7996
# val Loss: 0.6086 Acc: 0.7906
# Epoch 18/24
# ----------
# train Loss: 0.5694 Acc: 0.7999
# val Loss: 0.6049 Acc: 0.7870
# Epoch 19/24
# ----------
# train Loss: 0.5697 Acc: 0.7989
# val Loss: 0.5941 Acc: 0.7922
# Epoch 20/24
# ----------
# train Loss: 0.5714 Acc: 0.7986
# val Loss: 0.6162 Acc: 0.7834
# Epoch 21/24
# ----------
# train Loss: 0.5622 Acc: 0.8025
# val Loss: 0.6144 Acc: 0.7890
# Epoch 22/24
# ----------
# train Loss: 0.5636 Acc: 0.8024
# val Loss: 0.6175 Acc: 0.7898
# Epoch 23/24
# ----------
# train Loss: 0.5705 Acc: 0.8000
# val Loss: 0.6157 Acc: 0.7914
# Epoch 24/24
# ----------
# train Loss: 0.5715 Acc: 0.7983
# val Loss: 0.6144 Acc: 0.7838
# Training complete in 105m 4s
# Best val Acc: 0.792200
# Results for MobileNetV2:
# Best Validation Accuracy: 0.7922
# Test Accuracy: 0.8254
# Test Precision: 0.8267
# Test F1 Score: 0.8256
# Training Time: 6304.28 seconds
# ----------------------------------------
# Epoch 0/24
# ----------
# train Loss: 1.4187 Acc: 0.4882
# val Loss: 1.1094 Acc: 0.5950
# Epoch 1/24
# ----------
# train Loss: 1.0303 Acc: 0.6334
# val Loss: 0.9446 Acc: 0.6660
# Epoch 2/24
# ----------
# train Loss: 0.9168 Acc: 0.6763
# val Loss: 0.8711 Acc: 0.6962
# Epoch 3/24
# ----------
# train Loss: 0.8490 Acc: 0.7017
# val Loss: 0.8258 Acc: 0.7188
# Epoch 4/24
# ----------
# train Loss: 0.8006 Acc: 0.7190
# val Loss: 0.7923 Acc: 0.7270
# Epoch 5/24
# ----------
# train Loss: 0.7693 Acc: 0.7302
# val Loss: 0.7699 Acc: 0.7328
# Epoch 6/24
# ----------
# train Loss: 0.7455 Acc: 0.7381
# val Loss: 0.7384 Acc: 0.7462
# Epoch 7/24
# ----------
# train Loss: 0.6947 Acc: 0.7560
# val Loss: 0.7005 Acc: 0.7604
# Epoch 8/24
# ----------
# train Loss: 0.6754 Acc: 0.7639
# val Loss: 0.6943 Acc: 0.7664
# Epoch 9/24
# ----------
# train Loss: 0.6762 Acc: 0.7595
# val Loss: 0.6929 Acc: 0.7630
# Epoch 10/24
# ----------
# train Loss: 0.6630 Acc: 0.7672
# val Loss: 0.7047 Acc: 0.7594
# Epoch 11/24
# ----------
# train Loss: 0.6581 Acc: 0.7670
# val Loss: 0.6910 Acc: 0.7620
# Epoch 12/24
# ----------
# train Loss: 0.6535 Acc: 0.7701
# val Loss: 0.6869 Acc: 0.7654
# Epoch 13/24
# ----------
# train Loss: 0.6522 Acc: 0.7693
# val Loss: 0.6827 Acc: 0.7648
# Epoch 14/24
# ----------
# train Loss: 0.6509 Acc: 0.7704
# val Loss: 0.6889 Acc: 0.7620
# Epoch 15/24
# ----------
# train Loss: 0.6464 Acc: 0.7744
# val Loss: 0.6912 Acc: 0.7668
# Epoch 16/24
# ----------
# train Loss: 0.6456 Acc: 0.7720
# val Loss: 0.6767 Acc: 0.7676
# Epoch 17/24
# ----------
# train Loss: 0.6427 Acc: 0.7750
# val Loss: 0.6761 Acc: 0.7730
# Epoch 18/24
# ----------
# train Loss: 0.6382 Acc: 0.7758
# val Loss: 0.6822 Acc: 0.7666
# Epoch 19/24
# ----------
# train Loss: 0.6380 Acc: 0.7767
# val Loss: 0.6923 Acc: 0.7624
# Epoch 20/24
# ----------
# train Loss: 0.6426 Acc: 0.7753
# val Loss: 0.6766 Acc: 0.7636
# Epoch 21/24
# ----------
# train Loss: 0.6418 Acc: 0.7737
# val Loss: 0.6872 Acc: 0.7616
# Epoch 22/24
# ----------
# train Loss: 0.6375 Acc: 0.7744
# val Loss: 0.6780 Acc: 0.7616
# Epoch 23/24
# ----------
# train Loss: 0.6447 Acc: 0.7739
# val Loss: 0.6763 Acc: 0.7730
# Epoch 24/24
# ----------
# train Loss: 0.6395 Acc: 0.7768
# val Loss: 0.6809 Acc: 0.7636
# Training complete in 17m 50s
# Best val Acc: 0.773000
# Results for MobileNetV2:
# Best Validation Accuracy: 0.7730
# Test Accuracy: 0.8080
# Test Precision: 0.8080
# Test F1 Score: 0.8074
# Training Time: 1069.78 seconds
# ----------------------------------------
# Starting ResNet18 experiments...
# Epoch 0/24
# ----------
# train Loss: 1.2562 Acc: 0.5603
# val Loss: 1.0526 Acc: 0.6348
# Epoch 1/24
# ----------
# train Loss: 0.9157 Acc: 0.6830
# val Loss: 0.8837 Acc: 0.6976
# Epoch 2/24
# ----------
# train Loss: 0.8239 Acc: 0.7157
# val Loss: 0.9029 Acc: 0.6974
# Epoch 3/24
# ----------
# train Loss: 0.7659 Acc: 0.7362
# val Loss: 0.7840 Acc: 0.7254
# Epoch 4/24
# ----------
# train Loss: 0.7271 Acc: 0.7487
# val Loss: 0.7553 Acc: 0.7450
# Epoch 5/24
# ----------
# train Loss: 0.6930 Acc: 0.7580
# val Loss: 0.7495 Acc: 0.7434
# Epoch 6/24
# ----------
# train Loss: 0.6648 Acc: 0.7696
# val Loss: 0.7411 Acc: 0.7564
# Epoch 7/24
# ----------
# train Loss: 0.5740 Acc: 0.7998
# val Loss: 0.6290 Acc: 0.7850
# Epoch 8/24
# ----------
# train Loss: 0.5384 Acc: 0.8104
# val Loss: 0.6052 Acc: 0.7882
# Epoch 9/24
# ----------
# train Loss: 0.5223 Acc: 0.8169
# val Loss: 0.5851 Acc: 0.8056
# Epoch 10/24
# ----------
# train Loss: 0.5155 Acc: 0.8202
# val Loss: 0.5992 Acc: 0.7964
# Epoch 11/24
# ----------
# train Loss: 0.5090 Acc: 0.8227
# val Loss: 0.5865 Acc: 0.8040
# Epoch 12/24
# ----------
# train Loss: 0.4925 Acc: 0.8281
# val Loss: 0.5836 Acc: 0.8060
# Epoch 13/24
# ----------
# train Loss: 0.4865 Acc: 0.8280
# val Loss: 0.5809 Acc: 0.8054
# Epoch 14/24
# ----------
# train Loss: 0.4758 Acc: 0.8334
# val Loss: 0.5815 Acc: 0.8060
# Epoch 15/24
# ----------
# train Loss: 0.4736 Acc: 0.8366
# val Loss: 0.5851 Acc: 0.8082
# Epoch 16/24
# ----------
# train Loss: 0.4684 Acc: 0.8341
# val Loss: 0.5668 Acc: 0.8044
# Epoch 17/24
# ----------
# train Loss: 0.4681 Acc: 0.8354
# val Loss: 0.5742 Acc: 0.8028
# Epoch 18/24
# ----------
# train Loss: 0.4739 Acc: 0.8323
# val Loss: 0.5656 Acc: 0.8060
# Epoch 19/24
# ----------
# train Loss: 0.4681 Acc: 0.8349
# val Loss: 0.5720 Acc: 0.8124
# Epoch 20/24
# ----------
# train Loss: 0.4680 Acc: 0.8345
# val Loss: 0.5613 Acc: 0.8120
# Epoch 21/24
# ----------
# train Loss: 0.4670 Acc: 0.8352
# val Loss: 0.5863 Acc: 0.8070
# Epoch 22/24
# ----------
# train Loss: 0.4673 Acc: 0.8352
# val Loss: 0.5761 Acc: 0.8048
# Epoch 23/24
# ----------
# train Loss: 0.4668 Acc: 0.8355
# val Loss: 0.5804 Acc: 0.8014
# Epoch 24/24
# ----------
# train Loss: 0.4643 Acc: 0.8370
# val Loss: 0.5804 Acc: 0.8012
# Training complete in 17m 46s
# Best val Acc: 0.812400
# Results for ResNet18:
# Best Validation Accuracy: 0.8124
# Test Accuracy: 0.8424
# Test Precision: 0.8416
# Test F1 Score: 0.8416
# Training Time: 1066.02 seconds
# ----------------------------------------
# Epoch 0/24
# ----------
# train Loss: 1.4376 Acc: 0.4913
# val Loss: 1.0942 Acc: 0.6132
# Epoch 1/24
# ----------
# train Loss: 1.0271 Acc: 0.6384
# val Loss: 0.9682 Acc: 0.6610
# Epoch 2/24
# ----------
# train Loss: 0.9110 Acc: 0.6813
# val Loss: 0.8767 Acc: 0.7006
# Epoch 3/24
# ----------
# train Loss: 0.8339 Acc: 0.7087
# val Loss: 0.7949 Acc: 0.7288
# Epoch 4/24
# ----------
# train Loss: 0.7843 Acc: 0.7263
# val Loss: 0.7799 Acc: 0.7248
# Epoch 5/24
# ----------
# train Loss: 0.7467 Acc: 0.7414
# val Loss: 0.7565 Acc: 0.7388
# Epoch 6/24
# ----------
# train Loss: 0.7169 Acc: 0.7476
# val Loss: 0.7295 Acc: 0.7506
# Epoch 7/24
# ----------
# train Loss: 0.6656 Acc: 0.7662
# val Loss: 0.7102 Acc: 0.7530
# Epoch 8/24
# ----------
# train Loss: 0.6529 Acc: 0.7720
# val Loss: 0.6897 Acc: 0.7626
# Epoch 9/24
# ----------
# train Loss: 0.6405 Acc: 0.7753
# val Loss: 0.6932 Acc: 0.7578
# Epoch 10/24
# ----------
# train Loss: 0.6392 Acc: 0.7757
# val Loss: 0.6822 Acc: 0.7652
# Epoch 11/24
# ----------
# train Loss: 0.6348 Acc: 0.7789
# val Loss: 0.7048 Acc: 0.7554
# Epoch 12/24
# ----------
# train Loss: 0.6264 Acc: 0.7788
# val Loss: 0.6977 Acc: 0.7636
# Epoch 13/24
# ----------
# train Loss: 0.6228 Acc: 0.7802
# val Loss: 0.6742 Acc: 0.7694
# Epoch 14/24
# ----------
# train Loss: 0.6180 Acc: 0.7826
# val Loss: 0.6841 Acc: 0.7604
# Epoch 15/24
# ----------
# train Loss: 0.6144 Acc: 0.7852
# val Loss: 0.6774 Acc: 0.7702
# Epoch 16/24
# ----------
# train Loss: 0.6210 Acc: 0.7814
# val Loss: 0.6958 Acc: 0.7660
# Epoch 17/24
# ----------
# train Loss: 0.6195 Acc: 0.7821
# val Loss: 0.6859 Acc: 0.7666
# Epoch 18/24
# ----------
# train Loss: 0.6124 Acc: 0.7830
# val Loss: 0.6803 Acc: 0.7700
# Epoch 19/24
# ----------
# train Loss: 0.6168 Acc: 0.7848
# val Loss: 0.6781 Acc: 0.7670
# Epoch 20/24
# ----------
# train Loss: 0.6134 Acc: 0.7841
# val Loss: 0.6677 Acc: 0.7736
# Epoch 21/24
# ----------
# train Loss: 0.6134 Acc: 0.7861
# val Loss: 0.6910 Acc: 0.7656
# Epoch 22/24
# ----------
# train Loss: 0.6133 Acc: 0.7831
# val Loss: 0.6795 Acc: 0.7650
# Epoch 23/24
# ----------
# train Loss: 0.6130 Acc: 0.7849
# val Loss: 0.6593 Acc: 0.7754
# Epoch 24/24
# ----------
# train Loss: 0.6161 Acc: 0.7832
# val Loss: 0.6916 Acc: 0.7602
# Training complete in 18m 29s
# Best val Acc: 0.775400
# Results for ResNet18:
# Best Validation Accuracy: 0.7754
# Test Accuracy: 0.8039
# Test Precision: 0.8027
# Test F1 Score: 0.8027
# Training Time: 1108.74 seconds
# ----------------------------------------
#
# Starting VGG16 experiments...
# Epoch 0/24
# ----------
# train Loss: 1.0928 Acc: 0.6238
# val Loss: 0.8122 Acc: 0.7294
# Epoch 1/24
# ----------
# train Loss: 0.7275 Acc: 0.7570
# val Loss: 0.6941 Acc: 0.7694
# Epoch 2/24
# ----------
# train Loss: 0.6206 Acc: 0.7918
# val Loss: 0.6569 Acc: 0.7816
# Epoch 3/24
# ----------
# train Loss: 0.5538 Acc: 0.8126
# val Loss: 0.5659 Acc: 0.8186
# Epoch 4/24
# ----------
# train Loss: 0.5035 Acc: 0.8308
# val Loss: 0.5208 Acc: 0.8244
# Epoch 5/24
# ----------
# train Loss: 0.4669 Acc: 0.8428
# val Loss: 0.5041 Acc: 0.8296
# Epoch 6/24
# ----------
# train Loss: 0.4395 Acc: 0.8528
# val Loss: 0.4815 Acc: 0.8376
# Epoch 7/24
# ----------
# train Loss: 0.3228 Acc: 0.8903
# val Loss: 0.3910 Acc: 0.8714
# Epoch 8/24
# ----------
# train Loss: 0.2930 Acc: 0.9006
# val Loss: 0.3948 Acc: 0.8672
# Epoch 9/24
# ----------
# train Loss: 0.2802 Acc: 0.9045
# val Loss: 0.3972 Acc: 0.8638
# Epoch 10/24
# ----------
# train Loss: 0.2742 Acc: 0.9064
# val Loss: 0.3856 Acc: 0.8732
# Epoch 11/24
# ----------
# train Loss: 0.2668 Acc: 0.9090
# val Loss: 0.3850 Acc: 0.8708
# Epoch 12/24
# ----------
# train Loss: 0.2529 Acc: 0.9126
# val Loss: 0.3806 Acc: 0.8768
# Epoch 13/24
# ----------
# train Loss: 0.2520 Acc: 0.9135
# val Loss: 0.3758 Acc: 0.8772
# Epoch 14/24
# ----------
# train Loss: 0.2392 Acc: 0.9179
# val Loss: 0.3629 Acc: 0.8824
# Epoch 15/24
# ----------
# train Loss: 0.2383 Acc: 0.9169
# val Loss: 0.3539 Acc: 0.8816
# Epoch 16/24
# ----------
# train Loss: 0.2328 Acc: 0.9193
# val Loss: 0.3631 Acc: 0.8824
# Epoch 17/24
# ----------
# train Loss: 0.2361 Acc: 0.9177
# val Loss: 0.3677 Acc: 0.8800
# Epoch 18/24
# ----------
# train Loss: 0.2332 Acc: 0.9201
# val Loss: 0.3623 Acc: 0.8756
# Epoch 19/24
# ----------
# train Loss: 0.2314 Acc: 0.9191
# val Loss: 0.3742 Acc: 0.8810
# Epoch 20/24
# ----------
# train Loss: 0.2300 Acc: 0.9200
# val Loss: 0.3681 Acc: 0.8774
# Epoch 21/24
# ----------
# train Loss: 0.2304 Acc: 0.9207
# val Loss: 0.3631 Acc: 0.8802
# Epoch 22/24
# ----------
# train Loss: 0.2329 Acc: 0.9206
# val Loss: 0.3820 Acc: 0.8744
# Epoch 23/24
# ----------
# train Loss: 0.2297 Acc: 0.9191
# val Loss: 0.3678 Acc: 0.8768
# Epoch 24/24
# ----------
# train Loss: 0.2313 Acc: 0.9209
# val Loss: 0.3708 Acc: 0.8790
# Training complete in 25m 28s
# Best val Acc: 0.882400
# Results for VGG16:
# Best Validation Accuracy: 0.8824
# Test Accuracy: 0.9015
# Test Precision: 0.9014
# Test F1 Score: 0.9014
# Training Time: 1528.31 seconds
# ----------------------------------------
# Epoch 0/24
# ----------
# train Loss: 1.1921 Acc: 0.5760
# val Loss: 0.8868 Acc: 0.6900
# Epoch 1/24
# ----------
# train Loss: 0.7789 Acc: 0.7328
# val Loss: 0.7795 Acc: 0.7294
# Epoch 2/24
# ----------
# train Loss: 0.6706 Acc: 0.7717
# val Loss: 0.6535 Acc: 0.7780
# Epoch 3/24
# ----------
# train Loss: 0.6080 Acc: 0.7921
# val Loss: 0.6211 Acc: 0.7874
# Epoch 4/24
# ----------
# train Loss: 0.5567 Acc: 0.8106
# val Loss: 0.5735 Acc: 0.8020
# Epoch 5/24
# ----------
# train Loss: 0.5218 Acc: 0.8206
# val Loss: 0.5423 Acc: 0.8246
# Epoch 6/24
# ----------
# train Loss: 0.4850 Acc: 0.8349
# val Loss: 0.5173 Acc: 0.8246
# Epoch 7/24
# ----------
# train Loss: 0.4269 Acc: 0.8543
# val Loss: 0.4584 Acc: 0.8476
# Epoch 8/24
# ----------
# train Loss: 0.4108 Acc: 0.8580
# val Loss: 0.4748 Acc: 0.8428
# Epoch 9/24
# ----------
# train Loss: 0.4096 Acc: 0.8586
# val Loss: 0.4606 Acc: 0.8378
# Epoch 10/24
# ----------
# train Loss: 0.3968 Acc: 0.8617
# val Loss: 0.4589 Acc: 0.8428
# Epoch 11/24
# ----------
# train Loss: 0.3902 Acc: 0.8638
# val Loss: 0.4723 Acc: 0.8434
# Epoch 12/24
# ----------
# train Loss: 0.3918 Acc: 0.8651
# val Loss: 0.4567 Acc: 0.8442
# Epoch 13/24
# ----------
# train Loss: 0.3896 Acc: 0.8663
# val Loss: 0.4644 Acc: 0.8438
# Epoch 14/24
# ----------
# train Loss: 0.3824 Acc: 0.8674
# val Loss: 0.4445 Acc: 0.8474
# Epoch 15/24
# ----------
# train Loss: 0.3854 Acc: 0.8666
# val Loss: 0.4569 Acc: 0.8430
# Epoch 16/24
# ----------
# train Loss: 0.3786 Acc: 0.8681
# val Loss: 0.4624 Acc: 0.8434
# Epoch 17/24
# ----------
# train Loss: 0.3784 Acc: 0.8711
# val Loss: 0.4461 Acc: 0.8496
# Epoch 18/24
# ----------
# train Loss: 0.3806 Acc: 0.8667
# val Loss: 0.4485 Acc: 0.8528
# Epoch 19/24
# ----------
# train Loss: 0.3805 Acc: 0.8680
# val Loss: 0.4647 Acc: 0.8478
# Epoch 20/24
# ----------
# train Loss: 0.3764 Acc: 0.8683
# val Loss: 0.4574 Acc: 0.8486
# Epoch 21/24
# ----------
# train Loss: 0.3769 Acc: 0.8680
# val Loss: 0.4433 Acc: 0.8476
# Epoch 22/24
# ----------
# train Loss: 0.3779 Acc: 0.8690
# val Loss: 0.4629 Acc: 0.8410
# Epoch 23/24
# ----------
# train Loss: 0.3781 Acc: 0.8694
# val Loss: 0.4578 Acc: 0.8446
# Epoch 24/24
# ----------
# train Loss: 0.3812 Acc: 0.8672
# val Loss: 0.4520 Acc: 0.8490
# Training complete in 25m 6s
# Best val Acc: 0.852800
# Results for VGG16:
# Best Validation Accuracy: 0.8528
# Test Accuracy: 0.8755
# Test Precision: 0.8751
# Test F1 Score: 0.8750
# Training Time: 1506.20 seconds
# ----------------------------------------
